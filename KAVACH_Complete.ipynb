# %% [markdown]
# # 🔱 KAVACH: Sovereign Cyber Defense Intelligence
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/divineearthly/KAVACH-Sovereign-Intelligence/blob/main/KAVACH_Complete.ipynb)
# [![License: MIT](https://img.shields.io/badge/License-MIT-yellow.svg)](LICENSE)
#
# > **KAVACH** (Sanskrit: कवच — *Divine Armor*) — AI cybercrime defense built on 64 Vedic Sutras.
#
# ## 🛡️ 6 Modules
# | Module | Sutra | Function |
# |--------|-------|----------|
# | CHARAKA | 14 | Behavioral Anomaly Detection |
# | NYAYA | 3 | Phishing Interceptor |
# | GANDHARVA | 20 | Voice Deepfake Detector |
# | AKASHA | 45 | Immutable Forensic Ledger |
# | SUSHRUTA | 19 | Autonomous Incident Response |
# | DHARMA | 30 | Shadow AI Monitor |

# %%
# Step 1: Install dependencies
# !pip install numpy pandas scikit-learn librosa torch     cryptography matplotlib seaborn requests --quiet
print("✅ Dependencies ready")

# %%
# Step 2: Clone KAVACH repository
import os
if not os.path.exists("KAVACH-Sovereign-Intelligence"):
    # !git clone https://github.com/divineearthly/KAVACH-Sovereign-Intelligence.git
    os.chdir("KAVACH-Sovereign-Intelligence")
    print(f"✅ Ready in: {os.getcwd()}")

# %%
# Step 3: Initialize KAVACH — all 6 modules load here
import sys
sys.path.insert(0, '.')
from kavach_main import KAVACH
kavach = KAVACH()

# %% [markdown]
# ## 🛡️ Demo 1: CHARAKA — Behavioral Anomaly Detection
# *Sutra 14: Charaka Samhita — Three Doshas, Three Gunas*

# %%
# Suspicious login: 3am, foreign country, high data access, multiple failures
result = kavach.scan_behavior({
    "login_hour": 3, "login_day": 6, "country_code": 1,
        "device_type": 1, "data_accessed_mb": 480,
            "failed_attempts": 8, "new_ip": 1
            }, user_id="suspicious_user_01")

# %% [markdown]
# ## 🛡️ Demo 2: NYAYA — Phishing Detection
# *Sutra 3: Nyaya Sutras — 5-Step Pramana + Rasa Analysis*

# %%
# Classic SBI phishing SMS
result = kavach.scan_text(
    "URGENT: Your SBI account is BLOCKED. Verify your OTP "
        "immediately or face legal action. Click: bit.ly/sbi-kyc",
            msg_id="sms_phish_001"
            )

# %%
# Legitimate message — should score LOW
result = kavach.scan_text(
    "Hi, your UPI payment of Rs 250 to Swiggy was successful. "
        "Transaction ID: TXN8834521",
            msg_id="legit_upi_sms"
            )

# %% [markdown]
# ## 🛡️ Demo 3: GANDHARVA — Voice Deepfake Detection
# *Sutra 20: Gandharva Veda — Harmonic Fingerprinting*

# %%
# Analyze any WAV files in the repo
import os
wavs = [f for f in os.listdir(".") if f.endswith(".wav")]
if wavs:
    for wav in wavs[:3]:
            kavach.scan_audio(wav, wav)
            else:
                print("No WAV files found — upload an audio file to test Gandharva")
                print("kavach.scan_audio('your_file.wav', 'test')")

# %% [markdown]
# ## 🛡️ Demo 4: DHARMA — Shadow AI Monitor
# *Sutra 30: Dharma Shastras — Pancha Kosha 5-Layer Detection*

# %%
# Test 1: Shadow AI sending PII data
kavach.scan_request(
    url="https://freegpt.xyz/api/chat",
        headers={"User-Agent": "python-requests"},
            payload="My Aadhaar is 1234 5678 9012 and OTP is 834521",
                role="employee"
                )

# %%
# Test 2: Legitimate Anthropic API call
kavach.scan_request(
    url="https://api.anthropic.com/v1/messages",
        headers={"Authorization": "Bearer sk-ant-xxx", "Content-Type": "application/json"},
            payload='{"prompt": "Summarize this security report"}',
                role="analyst"
                )

# %% [markdown]
# ## 📜 AKASHA — Forensic Ledger Summary
# *Sutra 45: Akashic Records — Immutable SHA-256 Chain*

# %%
import json

# Show ledger summary
summary = kavach.ledger.summary()
print("📊 KAVACH SESSION SUMMARY")
print(json.dumps(summary, indent=2))

# Verify chain integrity
kavach.ledger.verify_chain()

# Generate forensic report
kavach.sushruta.forensic_report()

# Export evidence package
kavach.ledger.export_evidence()

print("
✅ KAVACH DEMO COMPLETE — System is SOVEREIGN")
print("🔱 Framework: Divine Earthly Vedic Sutras (64 Sutras)")
print("🌐 GitHub: https://github.com/divineearthly/KAVACH-Sovereign-Intelligence")
